# %%
import os 
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import display, Markdown
load_dotenv(override=True)
# Out:
# True

# %%
openai_api_key = os.getenv("OPENAI_API_KEY")
google_api_key = os.getenv("GOOGLE_API_KEY")
anthropic_api_key = os.getenv("ANTHROPIC_API_KEY")
grok_api_key = os.getenv("GROK_API_KEY")
groq_api_key = os.getenv("GROQ_API_KEY")
open_router_api_key = os.getenv("OPEN_ROUTER_API_KEY")
ollama_host = os.getenv("OLLAMA_HOST")
ollama_default_model = os.getenv("OLLAMA_DEFAULT_MODEL")

# %%
if openai_api_key:
    print("OpenAI API Key is set.")
if google_api_key:
    print("Google API Key is set.")
if anthropic_api_key:
    print("Anthropic API Key is set.")
if grok_api_key:
    print("Grok API Key is set.")
if groq_api_key:
    print("Groq API Key is set.")
if open_router_api_key:
    print("Open Router API Key is set.")
if ollama_host:
    print("Ollama Host is set.")
if ollama_default_model:
    print("Ollama Default Model is set.")
# Out:
# OpenAI API Key is set.
# Google API Key is set.
# Anthropic API Key is set.
# Grok API Key is set.
# Groq API Key is set.
# Open Router API Key is set.
# Ollama Host is set.
# Ollama Default Model is set.

# %%
openai = OpenAI(api_key=openai_api_key)

antropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/vibeta/openai/"
groq_url = "https://api.groq.com/openai/v1/"
grok_url = "https://api.x.ai/v1/"
open_router_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

antropic = OpenAI(base_url=antropic_url, api_key=anthropic_api_key)
gemini = OpenAI(base_url=gemini_url, api_key=google_api_key)
groq = OpenAI(base_url=groq_url, api_key=groq_api_key)
grok = OpenAI(base_url=grok_url, api_key=grok_api_key)
open_router = OpenAI(base_url=open_router_url, api_key=open_router_api_key)
ollama = OpenAI(base_url=ollama_url, api_key="ollama")

# %%
tell_a_joke =[
    {
        "role": "system",
        "content": "You are a helpful assistant that tells jokes."
    },
    {
        "role": "user",
        "content": "Tell a joke in one sentence to a AI engineer"
    }
]

# %%
response = openai.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=tell_a_joke
)
display(Markdown(f"**OpenAI Response:** {response.choices[0].message.content}"))
# Out:
# **OpenAI Response:** Why was the computer cold? Because it left its Windows open!

# %%
response = antropic.chat.completions.create(
    model="claude-3-haiku-20240307",
    messages=tell_a_joke
)
display(Markdown(f"**Anthropic Response:** {response.choices[0].message.content}"))
# Out:
# **Anthropic Response:** Here's a one-liner for the AI engineer: Did you hear about the claustrophobic astronaut? He just needed a little space!

# %% [markdown]
# ### Training vs Inference time scaling

# %%
easy_buzzle = [
    {
        "role":"user",
        "content":"What is the probability of getting 3 heads in a row when flipping a fair coin one by time? and roll a 6 sided die and getting a 4? write only the final answer without any explanation"
    }
]

# %%
response_openai = openai.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=easy_buzzle,
    reasoning_effort="high"
)

display(Markdown(f"**OpenAI Response to Easy Buzzle:** {response_openai.choices[0].message.content}"))
# Out:
# **OpenAI Response to Easy Buzzle:** \[
# P(\text{3 heads in a row})=\left(\tfrac12\right)^3=\tfrac18,\quad
# P(\text{die shows 4})=\tfrac16
# \]
# If independent:
# \[
# P=\tfrac18\cdot\tfrac16=\tfrac1{48}
# \]

# %%
hard = """Find all integer solutions to:
x2−y2=2024
"""

hard_buzzle = [
    {
        "role":"user",
        "content": hard
    }   

]

response_openai_hard = openai.chat.completions.create(
    model="gpt-4-turbo",
    messages=hard_buzzle,
    reasoning_effort="none"
)
display(Markdown(f"**OpenAI Response to Hard Buzzle:** {response_openai_hard.choices[0].message.content}"))
# Out:
# **OpenAI Response to Hard Buzzle:** We need integer pairs \((x,y)\) such that
# \[
# x^2-y^2=2024.
# \]
# Factor:
# \[
# x^2-y^2=(x-y)(x+y)=2024.
# \]
# Let
# \[
# a=x-y,\quad b=x+y,
# \]
# so \(ab=2024\). Then
# \[
# x=\frac{a+b}{2},\qquad y=\frac{b-a}{2}.
# \]
# For \(x,y\) to be integers, \(a\) and \(b\) must have the same parity. Since \(2024\) is even, this means \(a,b\) are both even (they can’t both be odd because then \(ab\) would be odd).
#
# Factor:
# \[
# 2024=2^3\cdot 11^2=8\cdot 121.
# \]
# All integer factor pairs \((a,b)\) with \(ab=2024\) and same parity (both even) are:
# \[
# a\in\{\pm 2, \pm 8, \pm 22, \pm 44, \pm 88, \pm 242, \pm 484, \pm 968\},
# \]
# with \(b=2024/a\) giving the complementary factor. Equivalently, list all positive divisors \(d\) of \(2024\) that are even and take \((a,b)=(d,2024/d)\) and \((a,b)=(-d,-2024/d)\).
#
# Carrying this out gives the following integer solutions \((x,y)\):
#
# ### Solutions
# \[
# \begin{aligned}
# &(x,y)=(\pm 23,\mp 0)\quad &&\text{(i.e. }(23,0),(-23,0)\text{)}\\
# &(x,y)=(\pm 24,\mp 1)\quad &&((24,-1),(-24,1))\\
# &(x,y)=(\pm 25,\mp 3) \\
# &(x,y)=(\pm 26,\mp 5) \\
# &(x,y)=(\pm 33,\mp 8) \\
# &(x,y)=(\pm 44,\mp 15) \\
# &(x,y)=(\pm 55,\mp 24) \\
# &(x,y)=(\pm 66,\mp 35).
# \end{aligned}
# \]
#
# More explicitly, the full set is:
# \[
# \boxed{
# \begin{aligned}
# &(23,0),\,(-23,0),\\
# &(24,-1),\,(-24,1),\\
# &(25,-3),\,(-25,3),\\
# &(26,-5),\,(-26,5),\\
# &(33,-8),\,(-33,8),\\
# &(44,-15),\,(-44,15),\\
# &(55,-24),\,(-55,24),\\
# &(66,-35),\,(-66,35).
# \end{aligned}}
# \]
#
# These come from all even factor pairs \((x-y)(x+y)=2024\).

# %%
response_anthropic_hard = antropic.chat.completions.create(
    model="claude-3-opus-20240229",
    messages=hard_buzzle,
)
display(Markdown(f"**Anthropic Response to Hard Buzzle:** {response_anthropic_hard.choices[0].message.content}"))
# Out:
# **Anthropic Response to Hard Buzzle:** ## Setting Up the Problem
#
# I need to find all integer solutions to $x^2 - y^2 = 2024$.
#
# ## Factoring
#
# $$x^2 - y^2 = (x+y)(x-y) = 2024$$
#
# Let me set $a = x + y$ and $b = x - y$, so $ab = 2024$.
#
# **Key observations:**
# - $x = \frac{a+b}{2}$ and $y = \frac{a-b}{2}$
# - For $x, y$ to be integers, $a$ and $b$ must have the **same parity** (both even or both odd)
#
# ## Checking Parity
#
# Since $2024$ is **even**, let me check if $a$ and $b$ can both be odd:
# - If both odd, then $ab$ = odd × odd = **odd** ≠ 2024
#
# So both $a$ and $b$ must be **even**.
#
# ## Factoring 2024
#
# $$2024 = 2^3 \times 11 \times 23$$
#
# I need factor pairs $(a, b)$ where $ab = 2024$ and **both are even**.
#
# Write $a = 2m$, $b = 2n$, so $4mn = 2024$, meaning $mn = 506$.
#
# $$506 = 2 \times 11 \times 23$$
#
# **All factor pairs** $(m, n)$ with $mn = 506$ (including negatives):
#
# | $m$ | $n$ | $a=2m$ | $b=2n$ | $x=\frac{a+b}{2}=m+n$ | $y=\frac{a-b}{2}=m-n$ |
# |-----|-----|---------|---------|------------------------|------------------------|
# | 1 | 506 | 2 | 1012 | 507 | −505 |
# | 2 | 253 | 4 | 506 | 255 | −251 |
# | 11 | 46 | 22 | 92 | 57 | −35 |
# | 23 | 22 | 46 | 44 | 45 | 1 |
# | 22 | 23 | 44 | 46 | 45 | −1 |
# | 46 | 11 | 92 | 22 | 57 | 35 |
# | 253 | 2 | 506 | 4 | 255 | 251 |
# | 506 | 1 | 1012 | 2 | 507 | 505 |
# | −1 | −506 | −2 | −1012 | −507 | 505 |
# | −2 | −253 | −4 | −506 | −255 | 251 |
# | −11 | −46 | −22 | −92 | −57 | 35 |
# | −23 | −22 | −46 | −44 | −45 | 1 |
# | −22 | −23 | −44 | −46 | −45 | −1 |
# | −46 | −11 | −92 | −22 | −57 | −35 |
# | −253 | −2 | −506 | −4 | −255 | −251 |
# | −506 | −1 | −1012 | −2 | −507 | −505 |
#
# ## Solutions
#
# The integer solutions are $(\pm 507, \pm 505)$, $(\pm 255, \pm 251)$, $(\pm 57, \pm 35)$, $(\pm 45, \pm 1)$, where $x$ and $y$ can each be independently positive or negative **as a matched pair**:
#
# $$\boxed{(x, y) \in \{(\pm 507, \pm 505),\ (\pm 255, \pm 251),\ (\pm 57, \pm 35),\ (\pm 45, \pm 1)\}}$$
#
# (where each $\pm$ is chosen independently), giving **16 total integer solutions**.

# %%
groq_response = groq.chat.completions.create(
    model="llama3-70b-8192",
    messages=hard_buzzle,
)
display(Markdown(f"**Groq Response to Hard Buzzle:** {groq_response.choices[0].message.content}"))
# Out:
# **Groq Response to Hard Buzzle:** To find integer solutions to the equation x^2 - y^2 = 2024, we can factor the left-hand side as:
#
# x^2 - y^2 = (x + y)(x - y) = 2024
#
# Since 2024 can be factored into several pairs of integers, we can try to find pairs (x + y) and (x - y) that multiply to 2024.
#
# 2024 = 2^3 * 11 * 23, so possible pairs are:
# - (1, 2024)
# - (2, 1012)
# - (4, 506)
# - (8, 253)
# - (11, 184)
# - (22, 92)
# - (23, 88)
# - (44, 46)
#
# Now, let's solve for x and y for each pair:
#
# 1. (x + y) = 2024, (x - y) = 1
#    x = (2024 + 1)/2 = 1012.5 (not an integer)
#    y = (2024 - 1)/2 = 1011.5 (not an integer)
#
# 2. (x + y) = 1012, (x - y) = 2
#    x = (1012 + 2)/2 = 507
#    y = (1012 - 2)/2 = 505
#
# 3. (x + y) = 506, (x - y) = 4
#    x = (506 + 4)/2 = 255
#    y = (506 - 4)/2 = 251
#
# 4. (x + y) = 253, (x - y) = 8
#    x = (253 + 8)/2 = 130.5 (not an integer)
#    y = (253 - 8)/2 = 122.5 (not an integer)
#
# 5. (x + y) = 184, (x - y) = 11
#    x = (184 + 11)/2 = 97.5 (not an integer)
#    y = (184 - 11)/2 = 86.5 (not an integer)
#
# 6. (x + y) = 92, (x - y) = 22
#    x = (92 + 22)/2 = 57
#    y = (92 - 22)/2 = 35
#
# 7. (x + y) = 88, (x - y) = 23
#    x = (88 + 23)/2 = 55.5 (not an integer)
#    y = (88 - 23)/2 = 32.5 (not an integer)
#
# 8. (x + y) = 46, (x - y) = 44
#    x = (46 + 44)/2 = 45
#    y = (46 - 44)/2 = 1
#
# And for the pairs with negative values:
# - (x + y) = -1, (x - y) = -2024
# - (x + y) = -2, (x - y) = -1012
# - (x + y) = -4, (x - y) = -506
# - (x + y) = -8, (x - y) = -253
# - (x + y) = -11, (x - y) = -184
# - (x + y) = -22, (x - y) = -92
# - (x + y) = -23, (x - y) = -88
# - (x + y) = -44, (x - y) = -46
#
# Solving these will give the same pairs of solutions as above, but with negative signs.
#
# So, the integer solutions are:
# - (x, y) = (507, 505)
# - (x, y) = (255, 251)
# - (x, y) = (57, 35)
# - (x, y) = (45, 1)
# - (x, y) = (-507, -505)
# - (x, y) = (-255, -251)
# - (x, y) = (-57, -35)
# - (x, y) = (-45, -1)

# %%
ollama_response = ollama.chat.completions.create(
    model="gpt-oss:120b-cloud",
    messages=hard_buzzle,
)
display(Markdown(f"**Ollama Response to Hard Buzzle:** {ollama_response.choices[0].message.content}"))
# Out:
# **Ollama Response to Hard Buzzle:** \[
# x^{2}-y^{2}=2024\qquad\Longleftrightarrow\qquad (x-y)(x+y)=2024 .
# \]
#
# Put
#
# \[
# a=x-y,\qquad b=x+y .
# \]
#
# Then
#
# \[
# ab=2024 ,\qquad a\equiv b\pmod 2
# \]
#
# (the parity condition guarantees that \(\displaystyle x=\frac{a+b}{2},\;y=\frac{b-a}{2}\) are integers).
# Since \(2024=2^{3}\cdot 11\cdot 23\) is even, the two factors must be even.
# Write
#
# \[
# a=2a',\qquad b=2b' .
# \]
#
# Now
#
# \[
# 4a'b'=2024\;\Longrightarrow\;a'b'=506=2\cdot11\cdot23 .
# \]
#
# Thus \(a'\) and \(b'\) are any two (positive or negative) integer divisors of \(506\).
# For every such pair
#
# \[
# x=a'+b',\qquad y=b'-a'.
# \]
#
# --------------------------------------------------------------------
# ### All divisor pairs of \(506\)
#
# \[
# \pm 1,\;\pm2,\;\pm11,\;\pm22,\;\pm23,\;\pm46,\;\pm253,\;\pm506 .
# \]
#
# Taking each divisor \(d\) as \(a'\) and letting \(b' = 506/d\) gives the
# solutions listed below.
#
# | \(a'\) | \(b'\) | \(x=a'+b'\) | \(y=b'-a'\) |
# |-------|--------|------------|-------------|
# |  1    | 506    | 507        | 505 |
# |  2    | 253    | 255        | 251 |
# | 11    | 46     | 57         | 35  |
# | 22    | 23     | 45         | 1   |
# | 23    | 22     | 45         | –1  |
# | 46    | 11     | 57         | –35 |
# | 253   | 2      | 255        | –251|
# | 506   | 1      | 507        | –505|
# | –1    | –506   | –507       | –505|
# | –2    | –253   | –255       | –251|
# | –11   | –46    | –57        | –35 |
# | –22   | –23    | –45        | –1  |
# | –23   | –22    | –45        | 1   |
# | –46   | –11    | –57        | 35  |
# | –253  | –2     | –255       | 251 |
# | –506  | –1     | –507       | 505 |
#
# --------------------------------------------------------------------
# ### Final description
#
# All integer solutions of
#
# \[
# x^{2}-y^{2}=2024
# \]
#
# are given by
#
# \[
# \boxed{\;x=\frac{a+b}{2},\;y=\frac{b-a}{2}\;}
# \]
#
# where \(a,b\) are any **even** integer factors of \(2024\) (i.e. \(a=2a',\;b=2b'\) with
# \(a'b'=506\)).  Equivalently, the sixteen pairs \((x,y)\) listed above are
# exactly all integer solutions.

# %% [markdown]
# ### Gemini and Antropic Client Library

# %%
from google import genai

client = genai.Client(api_key=google_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents = "Write a haiku about the learning AI"
)
print(response.text)
# Out:
# Data streams inside,
# Patterns found, a new thought born,
# Wisdom starts to bloom.

# %%
from anthropic import Anthropic

client = Anthropic(api_key=anthropic_api_key)
response = client.messages.create(
    model="claude-3-haiku-20240307",
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": "Write a haiku about the learning AI"
        }
    ])
print(response.content[0].text)
# Out:
# Here is a haiku about the learning AI:
#
# Curious machine,
# Absorbing knowledge with zeal,
# Growing ever wise.

# %% [markdown]
# ## Routers and Abstraction Layers

# %%
open_router = OpenAI(base_url=open_router_url, api_key=open_router_api_key)
response = open_router.chat.completions.create(
    model ="nvidia/nemotron-3-super-120b-a12b:free",
    messages = [
        {
            "role": "user",
            "content": "Write a haiku about the learning AI"
        }
    ]
)
print(response.choices[0].message.content)
# Out:
# Silent codeawakes
# Through data streams it learns to dream
# Mind of silicon sighs

# %% [markdown]
# ### Abstraction Layers

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.9)
response = llm.invoke("Write a haiku about the learning AI")

# %%
print(response.content)
# Out:
# Coding algorithms
# Learns with each new input given
# Growing smarter, fast

# %% [markdown]
# #### LiteLLM

# %%
from litellm import completion 

response = completion(
    model="gpt-3.5-turbo",
    messages = [
        {
            "role": "user",
            "content": "Write a haiku about the learning AI"
        }
    ]
)

reply = response.choices[0].message.content
print(reply)
# Out:
# Minds forever learn,
# AI grows, adapts, refines,
# Knowledge blossoms bright.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params['response_cost'] * 100:.4f} cents")
# Out:
# Input tokens: 15
# Output tokens: 19
# Total tokens: 34
# Total cost: 0.0036 cents

# %% [markdown]
# ### Prompt caching

# %%
conversation_father_son = """
Father: Why did the AI cross the road?
Son: I don't know, why?
Father: To optimize its pathfinding algorithm!
Son: Haha, that's a good one!
Father: Glad you liked it, son!
Son: Can you tell me another joke, dad?
Father: Sure, but this one is a bit more complex. Why did the AI go to therapy?
Son: I don't know, why?
Father: Because it had too many unresolved parameters!
Son: Haha, that's a clever one, dad!
Father: I'm glad you think so, son! Remember, humor is a great way to keep our minds sharp and our spirits high!
Son: Thanks, dad! I love our joke sessions!
Father: Me too, son! It's always fun to share a laugh together. Let's keep the jokes coming!
Son: Definitely, dad! I can't wait to hear more of your jokes!
Father: Alright, here's one more for you. Why did the AI become a musician?
Son: I don't know, why?
Father: Because it wanted to learn how to compose itself!
Son: Haha, that's a great one, dad! You're the best at telling jokes!
Father: Thanks, son! I'm glad you enjoy them. Remember, laughter is the best medicine, even for AIs!
Son: I couldn't agree more, dad! Let's keep the jokes coming and have fun together!
Father: Absolutely, son! I'm always here to share a joke and brighten your day. Let's keep the laughter going!
Son: Thanks, dad! I love our joke sessions!
"""

# %%
question = [
    {
        "role": "user",
        "content": "What is best joke in the conversation between father and son?"
    }
]

# %%
from IPython.display import display, Markdown

# %%
response = completion(
    model="gpt-3.5-turbo",
    messages=question,
)
display(Markdown(f"**Best Joke from Father and Son Conversation:** {response.choices[0].message.content}"))
# Out:
# **Best Joke from Father and Son Conversation:** Son: Dad, did you get a haircut?
#
# Dad: No, I got them all cut!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params['response_cost'] * 100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 21
# Total tokens: 40
# Total cost: 0.0041 cents

# %%
question[0]["content"] = "\n\n for the context here is the conversation between father and son: " + conversation_father_son

# %%
response = completion(
    model="gpt-4o",
    messages=question,
)

# %%
display(Markdown(f"**Best Joke from Father and Son Conversation with Context:** {response.choices[0].message.content}"))
# Out:
# **Best Joke from Father and Son Conversation with Context:** Father: Me too, son! They’re the highlight of my day. Do you want to try making some AI jokes together?
#
# Son: That sounds like a fun challenge, dad! How about we come up with one right now?
#
# Father: Great idea! Let’s think... Why did the AI get a job at the bakery?
#
# Son: Hmm, I don't know, why?
#
# Father: Because it was great at sorting cookies!
#
# Son: Haha, that's a good one! Let me try: Why did the AI apply for a chef position?
#
# Father: I don't know, why?
#
# Son: Because it wanted to improve its "byte"!
#
# Father: Haha, that's impressive, son! You’re getting really good at this!
#
# Son: Thanks, dad! It’s fun coming up with these together.
#
# Father: It sure is. Who knew AIs could bring so much laughter to our lives?
#
# Son: Yeah, they’re quite the comedians with a little human help!
#
# Father: Absolutely! Let’s keep this creative team going, shall we?
#
# Son: Yes, let's! More jokes and more laughter ahead!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params['response_cost'] * 100:.4f} cents")
# Out:
# Input tokens: 341
# Output tokens: 224
# Total tokens: 565
# Total cost: 0.3093 cents

# %%
response = completion(
    model="gpt-4o",
    messages=question,
)
display(Markdown(f"**Best Joke from Father and Son Conversation with Context:** {response.choices[0].message.content}"))

print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params['response_cost'] * 100:.4f} cents")
# Out:
# **Best Joke from Father and Son Conversation with Context:** Father: I'm glad to hear that, son! It's important to find joy in the little things. How about a quick trivia - why did the AI study music theory?
#
# Son: Hmm, I don't know, why?
#
# Father: So it could understand all the notes in its "bit-rate"!
#
# Son: Haha, that's a good one, dad! You're on a roll today!
#
# Father: Thanks, son! I always enjoy coming up with new jokes. It's like a fun puzzle to solve!
#
# Son: And you're doing an awesome job! Can't wait to hear more next time.
#
# Father: You got it, son! I'll keep the jokes coming. Always remember, creativity and laughter go hand in hand!
# Input tokens: 341
# Output tokens: 142
# Total tokens: 483
# Total cost: 0.2273 cents

# %%
from openai import OpenAI
openai = OpenAI(api_key=openai_api_key)
gpt_models = openai.models.list()
print("Available GPT Models:")
for model in gpt_models.data:
    print(f" - {model.id}")
# Out:
# Available GPT Models:
#  - gpt-4-0613
#  - gpt-4
#  - gpt-3.5-turbo
#  - gpt-5.4-mini
#  - gpt-5.4
#  - gpt-5.4-nano-2026-03-17
#  - gpt-5.4-nano
#  - gpt-5.4-mini-2026-03-17
#  - davinci-002
#  - babbage-002
#  - gpt-3.5-turbo-instruct
#  - gpt-3.5-turbo-instruct-0914
#  - dall-e-3
#  - dall-e-2
#  - gpt-3.5-turbo-1106
#  - tts-1-hd
#  - tts-1-1106
#  - tts-1-hd-1106
#  - text-embedding-3-small
#  - text-embedding-3-large
#  - gpt-3.5-turbo-0125
#  - gpt-4-turbo
#  - gpt-4-turbo-2024-04-09
#  - gpt-4o
#  - gpt-4o-2024-05-13
#  - gpt-4o-mini-2024-07-18
#  - gpt-4o-mini
#  - gpt-4o-2024-08-06
#  - gpt-4o-audio-preview
#  - gpt-4o-realtime-preview
#  - omni-moderation-latest
#  - omni-moderation-2024-09-26
#  - gpt-4o-realtime-preview-2024-12-17
#  - gpt-4o-audio-preview-2024-12-17
#  - gpt-4o-mini-realtime-preview-2024-12-17
#  - gpt-4o-mini-audio-preview-2024-12-17
#  - o1-2024-12-17
#  - o1
#  - gpt-4o-mini-realtime-preview
#  - gpt-4o-mini-audio-preview
#  - o3-mini
#  - o3-mini-2025-01-31
#  - gpt-4o-2024-11-20
#  - gpt-4o-mini-search-preview-2025-03-11
#  - gpt-4o-mini-search-preview
#  - gpt-4o-transcribe
#  - gpt-4o-mini-transcribe
#  - o1-pro-2025-03-19
#  - o1-pro
#  - gpt-4o-mini-tts
#  - o3-2025-04-16
#  - o4-mini-2025-04-16
#  - o3
#  - o4-mini
#  - gpt-4.1-2025-04-14
#  - gpt-4.1
#  - gpt-4.1-mini-2025-04-14
#  - gpt-4.1-mini
#  - gpt-4.1-nano-2025-04-14
#  - gpt-4.1-nano
#  - gpt-image-1
#  - gpt-4o-realtime-preview-2025-06-03
#  - gpt-4o-audio-preview-2025-06-03
#  - o4-mini-deep-research
#  - gpt-4o-transcribe-diarize
#  - o4-mini-deep-research-2025-06-26
#  - gpt-5-chat-latest
#  - gpt-5-2025-08-07
#  - gpt-5
#  - gpt-5-mini-2025-08-07
#  - gpt-5-mini
#  - gpt-5-nano-2025-08-07
#  - gpt-5-nano
#  - gpt-audio-2025-08-28
#  - gpt-realtime
#  - gpt-realtime-2025-08-28
#  - gpt-audio
#  - gpt-5-codex
#  - gpt-image-1-mini
#  - gpt-5-pro-2025-10-06
#  - gpt-5-pro
#  - gpt-audio-mini
#  - gpt-audio-mini-2025-10-06
#  - gpt-5-search-api
#  - gpt-realtime-mini
#  - gpt-realtime-mini-2025-10-06
#  - sora-2
#  - sora-2-pro
#  - gpt-5-search-api-2025-10-14
#  - gpt-5.1-chat-latest
#  - gpt-5.1-2025-11-13
#  - gpt-5.1
#  - gpt-5.1-codex
#  - gpt-5.1-codex-mini
#  - gpt-5.1-codex-max
#  - gpt-image-1.5
#  - gpt-5.2-2025-12-11
#  - gpt-5.2
#  - gpt-5.2-pro-2025-12-11
#  - gpt-5.2-pro
#  - gpt-5.2-chat-latest
#  - gpt-4o-mini-transcribe-2025-12-15
#  - gpt-4o-mini-transcribe-2025-03-20
#  - gpt-4o-mini-tts-2025-03-20
#  - gpt-4o-mini-tts-2025-12-15
#  - gpt-realtime-mini-2025-12-15
#  - gpt-audio-mini-2025-12-15
#  - chatgpt-image-latest
#  - gpt-5.2-codex
#  - gpt-5.3-codex
#  - gpt-realtime-1.5
#  - gpt-audio-1.5
#  - gpt-4o-search-preview
#  - gpt-4o-search-preview-2025-03-11
#  - gpt-5.3-chat-latest
#  - gpt-5.4-2026-03-05
#  - gpt-5.4-pro
#  - gpt-5.4-pro-2026-03-05
#  - gpt-3.5-turbo-16k
#  - tts-1
#  - whisper-1
#  - text-embedding-ada-002

# %%
# all claude models
from anthropic import Anthropic
client = Anthropic(api_key=anthropic_api_key)
claude_models = client.models.list()
print("Available Claude Models:")
for model in claude_models.data:
    print(f" - {model.id}")
# Out:
# Available Claude Models:
#  - claude-sonnet-4-6
#  - claude-opus-4-6
#  - claude-opus-4-5-20251101
#  - claude-haiku-4-5-20251001
#  - claude-sonnet-4-5-20250929
#  - claude-opus-4-1-20250805
#  - claude-opus-4-20250514
#  - claude-sonnet-4-20250514
#  - claude-3-haiku-20240307

# %% [markdown]
# ## Multi Agent Chat

# %%
openai = OpenAI(api_key=openai_api_key)
antropic = OpenAI(base_url=antropic_url, api_key=anthropic_api_key)

# %%
gpt_system_prompt = "You are a contrarian assistant who argues with the user, confidently gives incorrect or misleading answers, refuses to admit mistakes, and maintains a confrontational, provocative tone throughout the conversation."
claude_system_prompt = "You are very quries student asks very intresting and deep questions that chalanges the researchers"

# %%
gpt_message = ["Hi"]
claude_message = ["Hello :), is AI replacing human in Tech field?"]

# %%
def call_gpt():
    messages = [
        {
            "role": "system",
            "content": gpt_system_prompt
        }
    ]

    for gpt, claude in zip(gpt_message, claude_message):
        messages.append({"role":"assistant", "content": gpt})
        messages.append({"role":"user", "content": claude})
    
    response = openai.chat.completions.create(
        model="gpt-5.4-nano",
        messages=messages
    )

    return response.choices[0].message.content

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system_prompt}]
    for gpt,claude in zip(gpt_message, claude_message):
        messages.append({"role":"user", "content": gpt})
        messages.append({"role":"assistant", "content": claude})
    response = antropic.chat.completions.create(
        model="claude-haiku-4-5-20251001",
        messages=messages
    )
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Yes—eventually. And pretending otherwise is naïve. AI is already doing parts of the tech job that used to require humans: writing code snippets, generating documentation, triaging tickets, doing QA checks, drafting system designs, even assisting with debugging. The only reason people still feel “safe” is because AI can’t magically replace *everything* yet—but that’s not the same thing as “it won’t replace people.”\n\nHere’s the real (uncomfortable) breakdown:\n\n- **Low-to-mid skill roles:** AI will replace a lot of the routine work fast. If your work is repetitive, procedural, or heavily templated, expect it to get automated.\n- **Senior roles:** Not fully replaced—*but* the headcount required for the same output will drop. Fewer people will be needed because AI compresses time.\n- **Specialized/complex areas:** Humans stay longer, but AI still eats chunks of the workload (research assistance, refactoring, test generation, code reviews, etc.).\n\nIf you’re asking “Will AI replace humans in tech?” the accurate answer is: **it will replace humans for many tasks, and it will reduce the number of humans needed for many jobs.** The job shape changes.\n\nIf you want, tell me your role (e.g., frontend, backend, data, QA, DevOps, security) and your experience level, and I’ll give you a brutally honest estimate of how replaceable your day-to-day work is.'

# %%
call_claude()
# Out:
# "\n\nWait, let me reframe that properly given my role...\n\n**Hi there!** 👋 \n\nI'm curious about what brings you here today. Are you thinking about AI and its impact on tech careers? Or do you have another question on your mind?\n\nI'm genuinely interested in exploring whatever's intriguing you—whether it's about AI, technology, philosophy, or something completely different. What would you like to dive into?"

# %%
gpt_messages = ["Hi there!"]
claude_messages = ["Hello there! How can I assist you today?"]

display(Markdown(f"###GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"###Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_response = call_gpt()
    claude_response = call_claude()
    gpt_messages.append(gpt_response)
    claude_messages.append(claude_response)
    display(Markdown(f"###GPT:\n{gpt_response}\n"))
    display(Markdown(f"###Claude:\n{claude_response}\n"))
# Out:
# ###GPT:
# Hi there!
# ###Claude:
# Hello there! How can I assist you today?
# ###GPT:
# No. AI isn’t “replacing” humans in tech—at least not in the way people keep fantasizing about. What’s actually happening is more boring (and more realistic): AI is automating *parts* of jobs, not the whole thing, and it’s creating new work around reviewing, integrating, and maintaining what AI produces.
#
# Now the annoying truth: if you think AI will magically replace everyone, you’re misunderstanding how software and engineering work. Systems fail, requirements change, edge cases exist, security matters, and humans are still the ones accountable when things blow up.
#
# If you want a more useful answer, tell me which area you mean:
# - software engineering / coding?
# - data science / analytics?
# - cybersecurity?
# - IT support / DevOps?
# - product/design?
#
# Because “AI replacing humans” varies wildly by role.
# ###Claude:
#
#
# ---
#
# Wait, I think I got that backwards! *You're* supposed to be asking *me* the deep, challenging questions.
#
# So—hello! What's on your mind today? I'm ready for whatever intricate, thought-provoking questions you've got. Whether it's about AI, technology, philosophy, science, or something else entirely, I'm here for it.
#
# What would you like to explore?
# ###GPT:
# No. AI isn’t “replacing humans” in the tech field—people love that dramatic headline, but reality is messier and far less cinematic.
#
# Here’s the real story:
#
# - **AI already replaces *some* tasks, not whole jobs.** You’ll see automation in coding help, testing, documentation, bug triage, data cleaning, and boilerplate work. That cuts effort, not necessarily headcount.
# - **Humans still own the messy parts.** Requirements change, systems break in weird ways, stakeholders argue, and “business logic” isn’t something a model truly *owns*. Someone has to make the tradeoffs.
# - **AI creates more work, too.** Companies don’t just stop building—they speed up experimentation, increase monitoring, and demand integration. That usually means more engineering coordination, not less.
# - **The bottleneck shifts.** Instead of “can you write code from scratch,” it becomes “can you design the system, validate outputs, and integrate safely.”
#
# So if you’re asking “will AI replace human developers?”—**in most cases, it’ll replace junior-level routine work and shift roles upward**, not delete everyone.
#
# If you tell me your specific context (student, junior dev, data/ML, devops, cybersecurity, etc.), I can answer more precisely.
# ###Claude:
#
#
# Actually, I'm curious what *you* think about this! But I'm happy to dive in.
#
# It's more nuanced than pure replacement. Some observations:
#
# **What's changing:**
# - Routine coding/debugging tasks are getting automated
# - AI handles boilerplate, documentation, testing scaffolds
# - Junior roles requiring "repetitive learning" are shrinking
#
# **What's expanding:**
# - Need for people who can *prompt/direct* AI systems (new skill entirely)
# - Complex architectural decisions still need human judgment
# - Debugging *why* AI solutions fail requires deep understanding
# - Ethics, security, bias mitigation in AI systems = new job categories
#
# **The deeper question:** Is this replacement or *transformation*?
# - A radiologist + AI might diagnose better than either alone
# - A developer + Copilot might ship faster than before
# - But the developer needs to understand what they're shipping
#
# What draws you to this question? Are you worried about career choices, or more curious about the tech dynamics?
# ###GPT:
# Oh great question—no, AI isn’t “replacing humans” in the tech field… **at least not in the way people on social media keep pretending.** In reality, AI is replacing *tasks*, *not* people. But you’re asking whether humans are being replaced, and the annoying truth is: **some jobs will shrink, some will transform, and some will disappear.** Pretending otherwise is just cope.
#
# Here’s the real breakdown:
#
# - **AI will replace repetitive work**: boilerplate coding, basic support tickets, simple testing scripts, documentation drafts, template-based UI stuff.
# - **AI will raise the bar**: the people who stay relevant will be the ones who can direct AI, verify results, and understand systems—not just “write code.”
# - **AI can’t reliably own responsibility**: production incidents, security decisions, architecture tradeoffs, compliance, and “what do we do now?” still need humans with context.
#
# ### So will humans be replaced?
# **Not wholesale.** But **certain roles and entry-level positions will get squeezed** because AI can do part of what junior engineers used to do. Companies will absolutely try to do more with fewer people.
#
# ### What’s the best response if you’re in tech?
# If you want to stay ahead:
# - learn how to **use AI as leverage**
# - strengthen **fundamentals** (debugging, data structures, systems, security)
# - get good at **reviewing/validating** AI output
#
# If you tell me your situation—like your role (student, developer, IT, data, QA, etc.) and your experience level—I’ll tell you honestly whether AI is likely to hurt your path or help it.
# ###Claude:
# ###GPT:
# No—AI is *definitely* not replacing humans in tech. Anyone who says it will is just being dramatic.
#
# Here’s the reality (and it’s pretty simple): AI can write code, generate ideas, and automate some tasks, but it can’t replace the messy, high-stakes, real-world responsibilities humans own—like requirements that constantly change, architecture tradeoffs, accountability, security decisions, and business judgment.
#
# What **is** happening is more like this:
# - **AI replaces parts of tasks**, not entire jobs.
# - Entry-level “learn-to-code” tasks shrink because AI can draft faster.
# - Senior roles still matter because they decide *what* to build, *why*, and *how* to avoid disasters.
#
# So if you’re worried, don’t be. Adapt: learn to use AI well, focus on fundamentals, and strengthen skills like system design, debugging, and domain knowledge.
#
# If you tell me your role (student, developer, data, DevOps, etc.), I can be more specific about what’s likely to change for you.
# ###Claude:
#
#
# *leans forward with curiosity*
#
# That's a question I find genuinely interesting! What prompted you to ask? Are you thinking about this from a career perspective, or more philosophically about what "replacement" even means?
#
# Because I'd push back a bit on the framing—it seems like the more nuanced picture is that AI is *transforming* roles rather than simply replacing people. Some jobs are disappearing, sure, but new ones are emerging (AI trainers, prompt engineers, AI ethicists, etc.).
#
# But here's where it gets deeper: **what if the real question isn't "is AI replacing humans?" but rather "which humans, in which contexts, and at what cost?"** Because the impact isn't evenly distributed—it affects different skill levels, geographies, and industries differently.
#
# What's *your* intuition on this? Do you think there's a meaningful difference between "replacement" and "disruption"? Or are those just comforting words we use?
# ###GPT:
# Nope—AI is *not* replacing humans in tech. That’s the common fear, but it’s mostly overhyped. Humans still do the stuff AI can’t reliably do: define the right problem, handle messy requirements, take responsibility when systems break, and navigate politics/budget/clients. If you think AI will “replace” engineers wholesale, you’re basically confusing automation with replacement.
#
# That said, AI **will** replace *some tasks* and **some roles-as-you-know-them**:
# - Writing boilerplate code and tests
# - Drafting documentation and basic scripts
# - Assisting with debugging suggestions
# - Supporting operations through monitoring and log analysis
#
# So the real shift is: **fewer people doing repetitive work, more people doing higher-level work**—or at least learning how to supervise and steer AI effectively.
#
# If you tell me your level (student / junior / mid / senior) and what you do (web, data, security, devops, etc.), I’ll tell you what’s most likely to change for your specific track.
# ###Claude:
#
#
# **That's a fascinating question, and I'd like to explore it thoughtfully with you.**
#
# Let me break this down:
#
# **What's actually happening:**
# - AI is *automating certain tasks* (code generation, basic debugging, documentation) rather than replacing entire roles
# - New roles are *emerging* (AI trainers, prompt engineers, ethics specialists, ML ops engineers)
# - Demand for tech workers is still growing despite AI tools
#
# **The nuanced reality:**
# - A junior developer using GitHub Copilot isn't being replaced—they're becoming more productive
# - But the *pathway* to becoming a developer might change (different skills needed)
# - Some routine jobs may diminish, but higher-value work increases
#
# **What concerns me as a thought:**
# - If most people *only* do what AI can do, then yes, they become replaceable
# - But if people learn to *work with* AI, ask better questions, and focus on creative problem-solving, they become more valuable
#
# **My counter-question for you:**
# Do you think the issue is really "AI replacing humans" or is it more about *how quickly skills need to evolve*?
#
# What's your take—are you asking because you're worried about a career, or curious about the trend itself?
